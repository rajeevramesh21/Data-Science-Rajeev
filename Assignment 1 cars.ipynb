# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Cars.csv')

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
df.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
df['HP'].dtype#Continuous
# Out:
# dtype('int64')

# %%
df['MPG'].dtype#Continuous, All columns being continuous
# Out:
# dtype('float64')

# %%
df.shape
# Out:
# (81, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
# HP     81 non-null int64
# MPG    81 non-null float64
# VOL    81 non-null int64
# SP     81 non-null float64
# WT     81 non-null float64
# dtypes: float64(3), int64(2)
# memory usage: 3.2 KB

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df['HP'].plot(kind='hist')

# %%
min(df['HP']),max(df['HP'])
# Out:
# (49, 322)

# %%
df.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
df.plot(kind='box', title='Distribution', figsize = (15,10))#Studying boxplots for outliers
plt.show()

# %%
df['WT'].plot(kind='box', title='WT')
plt.show()

# %%
VolWt=df[['WT','VOL']]

# %%
VolWt.plot(kind='scatter',x='WT',y='VOL')#Some linearity found

# %%
HpSp=df[['HP','SP']]

# %%
HpSp.plot(kind='scatter',x='HP',y='SP')
